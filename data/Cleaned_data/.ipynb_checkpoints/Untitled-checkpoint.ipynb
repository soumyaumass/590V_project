# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
import glob
from datetime import datetime

# %%
def genIce(data, level, level_name):
    data_len, _ = data.shape
    print("data len = ", data_len)
    block_len = int(np.ceil(data_len/level))
    print("block_len", block_len)
    scores = []
    total_durations = []
    for i in range(level):
        start = i*block_len
        end = min(data_len, (i+1)*block_len)
        print("start = ", start, "  end = ", end)
        #print(df['duration'][start:end])
        #print(df['truth_int'][start:end])
        #print(df['weighted_truth'][start:end])
        total_duration = df['duration'][start:end].sum()
        total_durations.append(total_duration)
        #print(weighted_sum)
        #durations = df['duration'][start:end]
        #truth_ints = df['truth_int'][start:end]
        #print("truth_ints: ")
        #print(truth_ints)
        df_tmp = df[start:end]
        print(df_tmp['truth_int'])
        print(df_tmp['duration'])
        duration_3 = df_tmp.loc[df_tmp['truth_int'] == 3, 'duration'].sum()
        duration_2 = df_tmp.loc[df_tmp['truth_int'] == 2, 'duration'].sum()
        duration_1 = df_tmp.loc[df_tmp['truth_int'] == 1, 'duration'].sum()
        duration_0 = df_tmp.loc[df_tmp['truth_int'] == 0, 'duration'].sum()
        duration_unk = df_tmp.loc[df_tmp['truth_int'] == -1, 'duration'].sum()
        print("3: ", duration_3, "2: ", duration_2, "1: ", duration_1, "0: ", duration_0, "-1: ", duration_unk)
        
        print("total_duration = ",total_duration)
        assert(total_duration == duration_2 + duration_3+ duration_1+ duration_0+ duration_unk)
        dur_scores = []
        dur_scores.append(duration_unk)
        dur_scores.append(duration_0)
        dur_scores.append(duration_1)
        dur_scores.append(duration_2)
        dur_scores.append(duration_3)
        
        maxId = np.argmax(dur_scores)
        print("max Id: ", maxId-1)
        scores.append(maxId-1)
        #print(weighted_sum/duration)
        #print(round(weighted_sum/duration))
        #scores.append(round(weighted_sum/duration))
    return scores, total_durations

# %%
allFiles = glob.glob("*.csv")
movies = {}
for filename in allFiles:
    print(filename)
    name = (filename.split('.'))[0]
    print(name)
    df = pd.read_csv(filename)
    #print(df)
    #df['truth_int'] = df['truth_int'].astype('int64')
    try:
        df["weighted_truth"] = df['truth_int']*df['duration']
        division = [27, 9, 3, 1]
        for div in division:
            scores, total_durations = genIce(df, div, "ice"+ str(div))
            scores_df = pd.DataFrame()
            scores_df['truth_int'] = scores
            scores_df['duration'] = total_durations
            scores_df.to_csv(name+"_ice"+str(div)+".csv")
    except:
        print("failed for ", name)
# Out:
# TheSocialNetwork.csv
# TheSocialNetwork
# data len =  171
# block_len 7
# start =  0   end =  7
# 0    0
# 1    3
# 2    0
# 3    2
# 4    0
# 5    2
# 6    3
# Name: truth_int, dtype: int64
# 0    105
# 1     29
# 2     46
# 3     19
# 4    104
# 5    147
# 6     49
# Name: duration, dtype: int64
# 3:  78 2:  166 1:  0 0:  255 -1:  0
# total_duration =  499
# max Id:  0
# start =  7   end =  14
# 7     3
# 8     3
# 9     3
# 10    3
# 11    3
# 12    2
# 13    3
# Name: truth_int, dtype: int64
# 7     10
# 8     23
# 9     31
# 10    16
# 11     0
# 12    27
# 13    13
# Name: duration, dtype: int64
# 3:  93 2:  27 1:  0 0:  0 -1:  0
# total_duration =  120
# max Id:  3
# start =  14   end =  21
# 14    3
# 15    3
# 16    0
# 17    0
# 18   -1
# 19    0
# 20    3
# Name: truth_int, dtype: int64
# 14    20
# 15    54
# 16    53
# 17    15
# 18     4
# 19    10
# 20    44
# Name: duration, dtype: int64
# 3:  118 2:  0 1:  0 0:  78 -1:  4
# total_duration =  200
# max Id:  3
# start =  21   end =  28
# 21    3
# 22    0
# 23    3
# 24    0
# 25    0
# 26    0
# 27    3
# Name: truth_int, dtype: int64
# 21    27
# 22    22
# 23    21
# 24    35
# 25    33
# 26    42
# 27    15
# Name: duration, dtype: int64
# 3:  63 2:  0 1:  0 0:  132 -1:  0
# total_duration =  195
# max Id:  0
# start =  28   end =  35
# 28    3
# 29    3
# 30    3
# 31    3
# 32    3
# 33    1
# 34    0
# Name: truth_int, dtype: int64
# 28    43
# 29    47
# 30    12
# 31    23
# 32    33
# 33    23
# 34    28
# Name: duration, dtype: int64
# 3:  158 2:  0 1:  23 0:  28 -1:  0
# total_duration =  209
# max Id:  3
# start =  35   end =  42
# 35    0
# 36    2
# 37    2
# 38    3
# 39    3
# 40    3
# 41    2
# Name: truth_int, dtype: int64
# 35    46
# 36    42
# 37     9
# 38    46
# 39    73
# 40    47
# 41    92
# Name: duration, dtype: int64
# 3:  166 2:  143 1:  0 0:  46 -1:  0
# total_duration =  355
# max Id:  3
# start =  42   end =  49
# 42    3
# 43   -1
# 44    0
# 45    3
# 46    3
# 47    3
# 48    3
# Name: truth_int, dtype: int64
# 42    51
# 43    25
# 44     6
# 45     5
# 46     3
# 47     7
# 48     6
# Name: duration, dtype: int64
# 3:  72 2:  0 1:  0 0:  6 -1:  25
# total_duration =  103
# max Id:  3
# start =  49   end =  56
# 49    0
# 50    0
# 51   -1
# 52   -1
# 53    3
# 54    3
# 55    3
# Name: truth_int, dtype: int64
# 49     9
# 50    25
# 51    13
# 52    57
# 53    11
# 54    48
# 55    31
# Name: duration, dtype: int64
# 3:  90 2:  0 1:  0 0:  34 -1:  70
# total_duration =  194
# max Id:  3
# start =  56   end =  63
# 56    2
# 57    3
# 58    3
# 59    3
# 60    2
# 61    3
# 62    0
# Name: truth_int, dtype: int64
# 56    40
# 57    27
# 58    41
# 59    20
# 60     8
# 61    18
# 62    41
# Name: duration, dtype: int64
# 3:  106 2:  48 1:  0 0:  41 -1:  0
# total_duration =  195
# max Id:  3
# start =  63   end =  70
# 63    2
# 64    3
# 65    3
# 66    0
# 67    2
# 68    0
# 69    3
# Name: truth_int, dtype: int64
# 63    51
# 64    15
# 65    48
# 66    14
# 67    69
# 68    62
# 69    36
# Name: duration, dtype: int64
# 3:  99 2:  120 1:  0 0:  76 -1:  0
# total_duration =  295
# max Id:  2
# start =  70   end =  77
# 70    3
# 71    0
# 72    3
# 73    3
# 74    2
# 75    3
# 76    3
# Name: truth_int, dtype: int64
# 70    175
# 71     71
# 72     12
# 73     23
# 74     75
# 75     53
# 76     55
# Name: duration, dtype: int64
# 3:  318 2:  75 1:  0 0:  71 -1:  0
# total_duration =  464
# max Id:  3
# start =  77   end =  84
# 77    3
# 78    1
# 79    3
# 80    3
# 81    1
# 82    0
# 83    3
# Name: truth_int, dtype: int64
# 77     85
# 78    107
# 79     14
# 80     44
# 81     27
# 82     99
# 83     46
# Name: duration, dtype: int64
# 3:  189 2:  0 1:  134 0:  99 -1:  0
# total_duration =  422
# max Id:  3
# start =  84   end =  91
# 84   -1
# 85    3
# 86    2
# 87    3
# 88    3
# 89    3
# 90    1
# Name: truth_int, dtype: int64
# 84     68
# 85     77
# 86    131
# 87     68
# 88     23
# 89    205
# 90     11
# Name: duration, dtype: int64
# 3:  373 2:  131 1:  11 0:  0 -1:  68
# total_duration =  583
# max Id:  3
# start =  91   end =  98
# 91    3
# 92    3
# 93    3
# 94    2
# 95    3
# 96    3
# 97    3
# Name: truth_int, dtype: int64
# 91    32
# 92    32
# 93    11
# 94    30
# 95    15
# 96    45
# 97     2
# Name: duration, dtype: int64
# 3:  137 2:  30 1:  0 0:  0 -1:  0
# total_duration =  167
# max Id:  3
# start =  98   end =  105
# 98     3
# 99     3
# 100    3
# 101    3
# 102    3
# 103    3
# 104    3
# Name: truth_int, dtype: int64
# 98      8
# 99      7
# 100     9
# 101     2
# 102    21
# 103     8
# 104     8
# Name: duration, dtype: int64
# 3:  63 2:  0 1:  0 0:  0 -1:  0
# total_duration =  63
# max Id:  3
# start =  105   end =  112
# 105    0
# 106    3
# 107    0
# 108    2
# 109    3
# 110    3
# 111    2
# Name: truth_int, dtype: int64
# 105     8
# 106    26
# 107     1
# 108    20
# 109    14
# 110    54
# 111    10
# Name: duration, dtype: int64
# 3:  94 2:  30 1:  0 0:  9 -1:  0
# total_duration =  133
# max Id:  3
# start =  112   end =  119
# 112    2
# 113    3
# 114    2
# 115    2
# 116   -1
# 117    0
# 118    3
# Name: truth_int, dtype: int64
# 112    32
# 113    10
# 114    18
# 115    23
# 116    57
# 117     5
# 118    10
# Name: duration, dtype: int64
# 3:  20 2:  73 1:  0 0:  5 -1:  57
# total_duration =  155
# max Id:  2
# start =  119   end =  126
# 119    0
# 120    3
# 121    0
# 122   -1
# 123    0
# 124    3
# 125    2
# Name: truth_int, dtype: int64
# 119     7
# 120     9
# 121     4
# 122     7
# 123     2
# 124    22
# 125    31
# Name: duration, dtype: int64
# 3:  31 2:  31 1:  0 0:  13 -1:  7
# total_duration =  82
# max Id:  2
# start =  126   end =  133
# 126   -1
# 127    3
# 128    3
# 129    3
# 130    3
# 131    2
# 132    3
# Name: truth_int, dtype: int64
# 126     28
# 127     85
# 128    102
# 129     39
# 130     47
# 131     28
# 132     43
# Name: duration, dtype: int64
# 3:  316 2:  28 1:  0 0:  0 -1:  28
# total_duration =  372
# max Id:  3
# start =  133   end =  140
# 133    3
# 134    3
# 135    3
# 136    2
# 137    3
# 138    0
# 139    3
# Name: truth_int, dtype: int64
# 133    235
# 134    102
# 135    119
# 136     56
# 137     39
# 138     62
# 139     70
# Name: duration, dtype: int64
# 3:  565 2:  56 1:  0 0:  62 -1:  0
# total_duration =  683
# max Id:  3
# start =  140   end =  147
# 140    3
# 141    3
# 142    3
# 143    3
# 144    1
# 145    3
# 146    3
# Name: truth_int, dtype: int64
# 140    87
# 141    19
# 142    13
# 143    38
# 144    97
# 145    45
# 146    59
# Name: duration, dtype: int64
# 3:  261 2:  0 1:  97 0:  0 -1:  0
# total_duration =  358
# max Id:  3
# start =  147   end =  154
# 147    2
# 148    2
# 149    3
# 150    3
# 151    3
# 152    3
# 153    3
# Name: truth_int, dtype: int64
# 147     9
# 148     7
# 149    66
# 150    62
# 151    22
# 152    54
# 153    47
# Name: duration, dtype: int64
# 3:  251 2:  16 1:  0 0:  0 -1:  0
# total_duration =  267
# max Id:  3
# start =  154   end =  161
# 154    3
# 155    1
# 156    0
# 157    0
# 158    0
# 159    0
# 160    3
# Name: truth_int, dtype: int64
# 154    52
# 155     2
# 156    99
# 157    30
# 158    42
# 159    40
# 160    30
# Name: duration, dtype: int64
# 3:  82 2:  0 1:  2 0:  211 -1:  0
# total_duration =  295
# max Id:  0
# start =  161   end =  168
# 161    3
# 162    3
# 163    3
# 164    3
# 165    0
# 166    2
# 167    3
# Name: truth_int, dtype: int64
# 161    40
# 162    14
# 163    35
# 164    64
# 165     6
# 166    72
# 167    16
# Name: duration, dtype: int64
# 3:  169 2:  72 1:  0 0:  6 -1:  0
# total_duration =  247
# max Id:  3
# start =  168   end =  171
# 168    3
# 169    1
# 170    3
# Name: truth_int, dtype: int64
# 168    147
# 169     52
# 170    119
# Name: duration, dtype: int64
# 3:  266 2:  0 1:  52 0:  0 -1:  0
# total_duration =  318
# max Id:  3
# start =  175   end =  171
# Series([], Name: truth_int, dtype: int64)
# Series([], Name: duration, dtype: int64)
# 3:  0 2:  0 1:  0 0:  0 -1:  0
# total_duration =  0
# max Id:  -1
# start =  182   end =  171
# Series([], Name: truth_int, dtype: int64)
# Series([], Name: duration, dtype: int64)
# 3:  0 2:  0 1:  0 0:  0 -1:  0
# total_duration =  0
# max Id:  -1
# data len =  171
# block_len 19
# start =  0   end =  19
# 0     0
# 1     3
# 2     0
# 3     2
# 4     0
# 5     2
# 6     3
# 7     3
# 8     3
# 9     3
# 10    3
# 11    3
# 12    2
# 13    3
# 14    3
# 15    3
# 16    0
# 17    0
# 18   -1
# Name: truth_int, dtype: int64
# 0     105
# 1      29
# 2      46
# 3      19
# 4     104
# 5     147
# 6      49
# 7      10
# 8      23
# 9      31
# 10     16
# 11      0
# 12     27
# 13     13
# 14     20
# 15     54
# 16     53
# 17     15
# 18      4
# Name: duration, dtype: int64
# 3:  245 2:  193 1:  0 0:  323 -1:  4
# total_duration =  765
# max Id:  0
# start =  19   end =  38
# 19    0
# 20    3
# 21    3
# 22    0
# 23    3
# 24    0
# 25    0
# 26    0
# 27    3
# 28    3
# 29    3
# 30    3
# 31    3
# 32    3
# 33    1
# 34    0
# 35    0
# 36    2
# 37    2
# Name: truth_int, dtype: int64
# 19    10
# 20    44
# 21    27
# 22    22
# 23    21
# 24    35
# 25    33
# 26    42
# 27    15
# 28    43
# 29    47
# 30    12
# 31    23
# 32    33
# 33    23
# 34    28
# 35    46
# 36    42
# 37     9
# Name: duration, dtype: int64
# 3:  265 2:  51 1:  23 0:  216 -1:  0
# total_duration =  555
# max Id:  3
# start =  38   end =  57
# 38    3
# 39    3
# 40    3
# 41    2
# 42    3
# 43   -1
# 44    0
# 45    3
# 46    3
# 47    3
# 48    3
# 49    0
# 50    0
# 51   -1
# 52   -1
# 53    3
# 54    3
# 55    3
# 56    2
# Name: truth_int, dtype: int64
# 38    46
# 39    73
# 40    47
# 41    92
# 42    51
# 43    25
# 44     6
# 45     5
# 46     3
# 47     7
# 48     6
# 49     9
# 50    25
# 51    13
# 52    57
# 53    11
# 54    48
# 55    31
# 56    40
# Name: duration, dtype: int64
# 3:  328 2:  132 1:  0 0:  40 -1:  95
# total_duration =  595
# max Id:  3
# start =  57   end =  76
# 57    3
# 58    3
# 59    3
# 60    2
# 61    3
# 62    0
# 63    2
# 64    3
# 65    3
# 66    0
# 67    2
# 68    0
# 69    3
# 70    3
# 71    0
# 72    3
# 73    3
# 74    2
# 75    3
# Name: truth_int, dtype: int64
# 57     27
# 58     41
# 59     20
# 60      8
# 61     18
# 62     41
# 63     51
# 64     15
# 65     48
# 66     14
# 67     69
# 68     62
# 69     36
# 70    175
# 71     71
# 72     12
# 73     23
# 74     75
# 75     53
# Name: duration, dtype: int64
# 3:  468 2:  203 1:  0 0:  188 -1:  0
# total_duration =  859
# max Id:  3
# start =  76   end =  95
# 76    3
# 77    3
# 78    1
# 79    3
# 80    3
# 81    1
# 82    0
# 83    3
# 84   -1
# 85    3
# 86    2
# 87    3
# 88    3
# 89    3
# 90    1
# 91    3
# 92    3
# 93    3
# 94    2
# Name: truth_int, dtype: int64
# 76     55
# 77     85
# 78    107
# 79     14
# 80     44
# 81     27
# 82     99
# 83     46
# 84     68
# 85     77
# 86    131
# 87     68
# 88     23
# 89    205
# 90     11
# 91     32
# 92     32
# 93     11
# 94     30
# Name: duration, dtype: int64
# 3:  692 2:  161 1:  145 0:  99 -1:  68
# total_duration =  1165
# max Id:  3
# start =  95   end =  114
# 95     3
# 96     3
# 97     3
# 98     3
# 99     3
# 100    3
# 101    3
# 102    3
# 103    3
# 104    3
# 105    0
# 106    3
# 107    0
# 108    2
# 109    3
# 110    3
# 111    2
# 112    2
# 113    3
# Name: truth_int, dtype: int64
# 95     15
# 96     45
# 97      2
# 98      8
# 99      7
# 100     9
# 101     2
# 102    21
# 103     8
# 104     8
# 105     8
# 106    26
# 107     1
# 108    20
# 109    14
# 110    54
# 111    10
# 112    32
# 113    10
# Name: duration, dtype: int64
# 3:  229 2:  62 1:  0 0:  9 -1:  0
# total_duration =  300
# max Id:  3
# start =  114   end =  133
# 114    2
# 115    2
# 116   -1
# 117    0
# 118    3
# 119    0
# 120    3
# 121    0
# 122   -1
# 123    0
# 124    3
# 125    2
# 126   -1
# 127    3
# 128    3
# 129    3
# 130    3
# 131    2
# 132    3
# Name: truth_int, dtype: int64
# 114     18
# 115     23
# 116     57
# 117      5
# 118     10
# 119      7
# 120      9
# 121      4
# 122      7
# 123      2
# 124     22
# 125     31
# 126     28
# 127     85
# 128    102
# 129     39
# 130     47
# 131     28
# 132     43
# Name: duration, dtype: int64
# 3:  357 2:  100 1:  0 0:  18 -1:  92
# total_duration =  567
# max Id:  3
# start =  133   end =  152
# 133    3
# 134    3
# 135    3
# 136    2
# 137    3
# 138    0
# 139    3
# 140    3
# 141    3
# 142    3
# 143    3
# 144    1
# 145    3
# 146    3
# 147    2
# 148    2
# 149    3
# 150    3
# 151    3
# Name: truth_int, dtype: int64
# 133    235
# 134    102
# 135    119
# 136     56
# 137     39
# 138     62
# 139     70
# 140     87
# 141     19
# 142     13
# 143     38
# 144     97
# 145     45
# 146     59
# 147      9
# 148      7
# 149     66
# 150     62
# 151     22
# Name: duration, dtype: int64
# 3:  976 2:  72 1:  97 0:  62 -1:  0
# total_duration =  1207
# max Id:  3
# start =  152   end =  171
# 152    3
# 153    3
# 154    3
# 155    1
# 156    0
# 157    0
# 158    0
# 159    0
# 160    3
# 161    3
# 162    3
# 163    3
# 164    3
# 165    0
# 166    2
# 167    3
# 168    3
# 169    1
# 170    3
# Name: truth_int, dtype: int64
# 152     54
# 153     47
# 154     52
# 155      2
# 156     99
# 157     30
# 158     42
# 159     40
# 160     30
# 161     40
# 162     14
# 163     35
# 164     64
# 165      6
# 166     72
# 167     16
# 168    147
# 169     52
# 170    119
# Name: duration, dtype: int64
# 3:  618 2:  72 1:  54 0:  217 -1:  0
# total_duration =  961
# max Id:  3
# data len =  171
# block_len 57
# start =  0   end =  57
# 0     0
# 1     3
# 2     0
# 3     2
# 4     0
# 5     2
# 6     3
# 7     3
# 8     3
# 9     3
# 10    3
# 11    3
# 12    2
# 13    3
# 14    3
# 15    3
# 16    0
# 17    0
# 18   -1
# 19    0
# 20    3
# 21    3
# 22    0
# 23    3
# 24    0
# 25    0
# 26    0
# 27    3
# 28    3
# 29    3
# 30    3
# 31    3
# 32    3
# 33    1
# 34    0
# 35    0
# 36    2
# 37    2
# 38    3
# 39    3
# 40    3
# 41    2
# 42    3
# 43   -1
# 44    0
# 45    3
# 46    3
# 47    3
# 48    3
# 49    0
# 50    0
# 51   -1
# 52   -1
# 53    3
# 54    3
# 55    3
# 56    2
# Name: truth_int, dtype: int64
# 0     105
# 1      29
# 2      46
# 3      19
# 4     104
# 5     147
# 6      49
# 7      10
# 8      23
# 9      31
# 10     16
# 11      0
# 12     27
# 13     13
# 14     20
# 15     54
# 16     53
# 17     15
# 18      4
# 19     10
# 20     44
# 21     27
# 22     22
# 23     21
# 24     35
# 25     33
# 26     42
# 27     15
# 28     43
# 29     47
# 30     12
# 31     23
# 32     33
# 33     23
# 34     28
# 35     46
# 36     42
# 37      9
# 38     46
# 39     73
# 40     47
# 41     92
# 42     51
# 43     25
# 44      6
# 45      5
# 46      3
# 47      7
# 48      6
# 49      9
# 50     25
# 51     13
# 52     57
# 53     11
# 54     48
# 55     31
# 56     40
# Name: duration, dtype: int64
# 3:  838 2:  376 1:  23 0:  579 -1:  99
# total_duration =  1915
# max Id:  3
# start =  57   end =  114
# 57     3
# 58     3
# 59     3
# 60     2
# 61     3
# 62     0
# 63     2
# 64     3
# 65     3
# 66     0
# 67     2
# 68     0
# 69     3
# 70     3
# 71     0
# 72     3
# 73     3
# 74     2
# 75     3
# 76     3
# 77     3
# 78     1
# 79     3
# 80     3
# 81     1
# 82     0
# 83     3
# 84    -1
# 85     3
# 86     2
# 87     3
# 88     3
# 89     3
# 90     1
# 91     3
# 92     3
# 93     3
# 94     2
# 95     3
# 96     3
# 97     3
# 98     3
# 99     3
# 100    3
# 101    3
# 102    3
# 103    3
# 104    3
# 105    0
# 106    3
# 107    0
# 108    2
# 109    3
# 110    3
# 111    2
# 112    2
# 113    3
# Name: truth_int, dtype: int64
# 57      27
# 58      41
# 59      20
# 60       8
# 61      18
# 62      41
# 63      51
# 64      15
# 65      48
# 66      14
# 67      69
# 68      62
# 69      36
# 70     175
# 71      71
# 72      12
# 73      23
# 74      75
# 75      53
# 76      55
# 77      85
# 78     107
# 79      14
# 80      44
# 81      27
# 82      99
# 83      46
# 84      68
# 85      77
# 86     131
# 87      68
# 88      23
# 89     205
# 90      11
# 91      32
# 92      32
# 93      11
# 94      30
# 95      15
# 96      45
# 97       2
# 98       8
# 99       7
# 100      9
# 101      2
# 102     21
# 103      8
# 104      8
# 105      8
# 106     26
# 107      1
# 108     20
# 109     14
# 110     54
# 111     10
# 112     32
# 113     10
# Name: duration, dtype: int64
# 3:  1389 2:  426 1:  145 0:  296 -1:  68
# total_duration =  2324
# max Id:  3
# start =  114   end =  171
# 114    2
# 115    2
# 116   -1
# 117    0
# 118    3
# 119    0
# 120    3
# 121    0
# 122   -1
# 123    0
# 124    3
# 125    2
# 126   -1
# 127    3
# 128    3
# 129    3
# 130    3
# 131    2
# 132    3
# 133    3
# 134    3
# 135    3
# 136    2
# 137    3
# 138    0
# 139    3
# 140    3
# 141    3
# 142    3
# 143    3
# 144    1
# 145    3
# 146    3
# 147    2
# 148    2
# 149    3
# 150    3
# 151    3
# 152    3
# 153    3
# 154    3
# 155    1
# 156    0
# 157    0
# 158    0
# 159    0
# 160    3
# 161    3
# 162    3
# 163    3
# 164    3
# 165    0
# 166    2
# 167    3
# 168    3
# 169    1
# 170    3
# Name: truth_int, dtype: int64
# 114     18
# 115     23
# 116     57
# 117      5
# 118     10
# 119      7
# 120      9
# 121      4
# 122      7
# 123      2
# 124     22
# 125     31
# 126     28
# 127     85
# 128    102
# 129     39
# 130     47
# 131     28
# 132     43
# 133    235
# 134    102
# 135    119
# 136     56
# 137     39
# 138     62
# 139     70
# 140     87
# 141     19
# 142     13
# 143     38
# 144     97
# 145     45
# 146     59
# 147      9
# 148      7
# 149     66
# 150     62
# 151     22
# 152     54
# 153     47
# 154     52
# 155      2
# 156     99
# 157     30
# 158     42
# 159     40
# 160     30
# 161     40
# 162     14
# 163     35
# 164     64
# 165      6
# 166     72
# 167     16
# 168    147
# 169     52
# 170    119
# Name: duration, dtype: int64
# 3:  1951 2:  244 1:  151 0:  297 -1:  92
# total_duration =  2735
# max Id:  3
# data len =  171
# block_len 171
# start =  0   end =  171
# 0      0
# 1      3
# 2      0
# 3      2
# 4      0
# 5      2
# 6      3
# 7      3
# 8      3
# 9      3
# 10     3
# 11     3
# 12     2
# 13     3
# 14     3
# 15     3
# 16     0
# 17     0
# 18    -1
# 19     0
# 20     3
# 21     3
# 22     0
# 23     3
# 24     0
# 25     0
# 26     0
# 27     3
# 28     3
# 29     3
#       ..
# 141    3
# 142    3
# 143    3
# 144    1
# 145    3
# 146    3
# 147    2
# 148    2
# 149    3
# 150    3
# 151    3
# 152    3
# 153    3
# 154    3
# 155    1
# 156    0
# 157    0
# 158    0
# 159    0
# 160    3
# 161    3
# 162    3
# 163    3
# 164    3
# 165    0
# 166    2
# 167    3
# 168    3
# 169    1
# 170    3
# Name: truth_int, Length: 171, dtype: int64
# 0      105
# 1       29
# 2       46
# 3       19
# 4      104
# 5      147
# 6       49
# 7       10
# 8       23
# 9       31
# 10      16
# 11       0
# 12      27
# 13      13
# 14      20
# 15      54
# 16      53
# 17      15
# 18       4
# 19      10
# 20      44
# 21      27
# 22      22
# 23      21
# 24      35
# 25      33
# 26      42
# 27      15
# 28      43
# 29      47
#       ...
# 141     19
# 142     13
# 143     38
# 144     97
# 145     45
# 146     59
# 147      9
# 148      7
# 149     66
# 150     62
# 151     22
# 152     54
# 153     47
# 154     52
# 155      2
# 156     99
# 157     30
# 158     42
# 159     40
# 160     30
# 161     40
# 162     14
# 163     35
# 164     64
# 165      6
# 166     72
# 167     16
# 168    147
# 169     52
# 170    119
# Name: duration, Length: 171, dtype: int64
# 3:  4178 2:  1046 1:  319 0:  1172 -1:  259
# total_duration =  6974
# max Id:  3

# %%
score = pd.read_csv("selma_ice8.csv")

# %%
score.head()
# Out:
#    Unnamed: 0    0
# 0           0  3.0
# 1           1  3.0
# 2           2  3.0
# 3           3  3.0
# 4           4  2.0
