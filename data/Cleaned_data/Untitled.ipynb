# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
import glob
from datetime import datetime

# %%
def genIce(data, level, level_name):
    data_len, _ = data.shape
    print("data len = ", data_len)
    block_len = data_len//level
    print("block_len", block_len)
    scores = []
    for i in range(level):
        start = i*block_len
        end = min(data_len, (i+1)*block_len)
        print("start = ", start, "  end = ", end)
        weighted_sum = df['weighted_truth'][start:end].sum()
        print(weighted_sum)
        duration = df['duration'][start:end].sum()
        print(duration)
        print(weighted_sum/duration)
        print(round(weighted_sum/duration))
        scores.append(round(weighted_sum/duration))
    return scores

# %%
allFiles = glob.glob("Selma.csv")
movies = {}
for filename in allFiles:
    print(filename)
    name = (filename.split('.'))[0]
    print(name)
    df = pd.read_csv(filename)
    print(df.columns)
    df["weighted_truth"] = df['truth_int']*df['duration']
    division = [8, 4, 2, 1]
    for div in division:
        scores = genIce(df, div, "ice"+ str(div))
        scores_df = pd.DataFrame(scores)
        scores_df.to_csv(name+"_ice"+str(div)+".csv")
# Out:
# Selma.csv
# Selma
# Index(['Unnamed: 0', 'truth_int', 'fiction type ', 'film_condensed',
#        'reality_condensed', 'duration'],
#       dtype='object')
# data len =  76
# block_len 9
# start =  0   end =  9
# 2460
# 910
# 2.7032967032967035
# 3.0
# start =  9   end =  18
# 2880
# 996
# 2.891566265060241
# 3.0
# start =  18   end =  27
# 1695
# 656
# 2.5838414634146343
# 3.0
# start =  27   end =  36
# 2534
# 1013
# 2.5014807502467917
# 3.0
# start =  36   end =  45
# 1818
# 790
# 2.30126582278481
# 2.0
# start =  45   end =  54
# 1055
# 424
# 2.4882075471698113
# 2.0
# start =  54   end =  63
# 1643
# 649
# 2.531587057010786
# 3.0
# start =  63   end =  72
# 1970
# 1046
# 1.8833652007648183
# 2.0
# data len =  76
# block_len 19
# start =  0   end =  19
# 5625
# 2001
# 2.811094452773613
# 3.0
# start =  19   end =  38
# 4008
# 1606
# 2.4956413449564137
# 2.0
# start =  38   end =  57
# 2874
# 1305
# 2.2022988505747128
# 2.0
# start =  57   end =  76
# 5519
# 2229
# 2.4759982054733065
# 2.0
# data len =  76
# block_len 38
# start =  0   end =  38
# 9633
# 3607
# 2.670640421402828
# 3.0
# start =  38   end =  76
# 8393
# 3534
# 2.374929258630447
# 2.0
# data len =  76
# block_len 76
# start =  0   end =  76
# 18026
# 7141
# 2.524296317042431
# 3.0
